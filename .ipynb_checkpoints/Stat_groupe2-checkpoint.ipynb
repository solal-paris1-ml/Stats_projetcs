# %% [markdown]
# # Statistical Learning Project
#
# We need to categorize th problem. With the data we have, in this particular contexte, we want to classify in a book is rather a fiction or not.
#
# Here we have the analysing task. We don't need to pre-process (note that much I mean)
#
# Later, it will be interesting to transform the raw data with futher features (or transformation on the variables).
#
# We also need to adress all if this points:
#
# - The accuracy of the model. (we need to be careful with this)
# - The interpretability of the model.
# - The complexity of the model.
# - The scalability of the model.
# - How long does it take to build, train, and test the model?
# - How long does it take to make predictions using the model?
# - Does the model meet the business goal ?
#
# And also: Optimize hyperparameters with (grid search, random search or Bayesian optimisation)

# %% [raw]
# # Plan
#
# 1/ Exploratory data analysis
#
# a. Import data and packages
# b. Data wrangling
# c. Preprocessing
#
# 2/ Features engeenering
# a. Features selection
# b. new features
#
# 3/ Modelisation
# a. Parametric methods
# b. Non parametric methods
#
# 4/ Adjusting and choice of Hyperparmeters
# a. Logistic Regression
# b. Perceptron b
# c. Naive Bayes
# d. Decision Trees
# e. Support Vector Machine
# f. Naive Bayes
# g. k-Nearest Neighbors

# %% [markdown]
# # 1/ Exploratory data analysis

# %% [markdown]
# ## a. Import of packages and data
#
# ### -- packages

# %%
"""IMPORT OF PCK"""

import os
import glob
import tqdm
import re

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)


import pandas as pd
import numpy as np
from scipy import stats
import math
import scipy.signal as signal
import random

from pathlib import Path
from IPython.core.display import display, HTML #display(HTML(data.to_html())) to show all variables
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
"""DIRECTORY defintion"""
os.getcwd()
# Out:
# 'C:\\Users\\ville\\PycharmProjects\\stat_projetcs\\git_project_stat\\Stats_projetcs'

# %% [markdown]
# ### -- data

# %%
data_folder = Path(r"C:\Users\ville\PycharmProjects\stat_projetcs\git_project_stat\Stats_projetcs\Appr_Stat\data\Books_Dataset_20210108\archive")
bestsellers = data_folder / "bestsellers_with_categories.csv"
dta = pd.read_csv(bestsellers)
dta = dta.rename(columns={"User Rating": "Rating"})

# %% [markdown]
# ## b. Data Wrangling

# %% [markdown]
# We notice that our objective variable is of type string. In order to make our predictions and to be able to apply our models, we convert this variable in dummy
#
# With:
#
#     if value = 0, the book is a Fiction
#
#     if value = 1, the book is not a Fiction (Non Fiction)

# %%
#Convertion of the target variable "Genre" in numerical
dta["Genre"] = dta.Genre.replace(to_replace=['Fiction', 'Non Fiction'], value=[0, 1])

# %%
dta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     550 non-null    object
#  1   Author   550 non-null    object
#  2   Rating   550 non-null    float64
#  3   Reviews  550 non-null    int64
#  4   Price    550 non-null    int64
#  5   Year     550 non-null    int64
#  6   Genre    550 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 30.2+ KB

# %% [markdown]
# With the info method we can see that we have, for each column of the dataframe, 550 non null values. Each one of them is numerical except for "Name" and "Author" columns.
#
# In the next step we make sure that there are not nan value in the dataframe.

# %%
# We look for missing values:
def num_missing(x):
    return sum(x.isnull())
# Application on the dataframe:
print("Missing values by columns:")
print(dta.apply(num_missing, axis=0))
# Out:
# Missing values by columns:
# Name       0
# Author     0
# Rating     0
# Reviews    0
# Price      0
# Year       0
# Genre      0
# dtype: int64

# %% [markdown]
# From this step we conclude that thare are not nan values in the dataframe.
#
# Same verification but with values = 0.

# %%
dta.describe().transpose()
# Out:
#          count          mean           std     min     25%     50%       75%  \
# Rating   550.0      4.618364      0.226980     3.3     4.5     4.7      4.80
# Reviews  550.0  11953.281818  11731.132017    37.0  4058.0  8580.0  17253.25
# Price    550.0     13.100000     10.842262     0.0     7.0    11.0     16.00
# Year     550.0   2014.000000      3.165156  2009.0  2011.0  2014.0   2017.00
# Genre    550.0      0.563636      0.496385     0.0     0.0     1.0      1.00
#
#              max
# Rating       4.9
# Reviews  87841.0
# Price      105.0
# Year      2019.0
# Genre        1.0

# %% [markdown]
# We see that there are some zero values in the price columns, let's investigate this

# %%
plt.figure()
plt.hist(dta["Price"], bins=30, density=True)
plt.show()

# %% [markdown]
# After a quick look on Amazon, we constat that the price = 0 only for audio book (with Audible).
# This price is not representative of the price of the others books.

# %%
nul_price = dta.loc[dta["Price"] == 0]
nul_price
# Out:
#                                                   Name  \
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 116                        Frozen (Little Golden Book)
# 193                               JOURNEY TO THE ICE P
# 219                                  Little Blue Truck
# 358              The Constitution of the United States
# 381                                        The Getaway
# 461  The Short Second Life of Bree Tanner: An Eclip...
# 505                              To Kill a Mockingbird
# 506                              To Kill a Mockingbird
# 507                              To Kill a Mockingbird
# 508                              To Kill a Mockingbird
#
#                                Author  Rating  Reviews  Price  Year  Genre
# 42                        Jeff Kinney     4.8     4505      0  2011      0
# 71                        Jeff Kinney     4.8     6812      0  2013      0
# 116                         RH Disney     4.7     3642      0  2014      0
# 193                         RH Disney     4.6      978      0  2014      0
# 219                    Alice Schertle     4.9     1884      0  2014      0
# 358  Delegates of the Constitutional
#      4.8     2774      0  2016      1
# 381                       Jeff Kinney     4.8     5836      0  2017      0
# 461                   Stephenie Meyer     4.6     2122      0  2010      0
# 505                        Harper Lee     4.8    26234      0  2013      0
# 506                        Harper Lee     4.8    26234      0  2014      0
# 507                        Harper Lee     4.8    26234      0  2015      0
# 508                        Harper Lee     4.8    26234      0  2016      0

# %%
sns.countplot(x= nul_price['Genre'])
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %% [markdown]
# As we see previously, the book of price = 0 corresponds to "Audible books". Only 1/12 is a non fiction when the price = 0.
#
# This generalisation is not true for a price > 0, but it's a good indicator anyway.

# %% [markdown]
# ### -- Study of Genre variable

# %%
dta["Genre"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
dta["Genre"].value_counts()

# 310 Non fiction
# 240 Fiction
# Out:
# 1    310
# 0    240
# Name: Genre, dtype: int64

# %%
sns.countplot(x=dta['Genre'])
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
dta.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  Rating  Reviews  Price  Year  Genre
# 0                  JJ Smith     4.7    17350      8  2016      1
# 1              Stephen King     4.6     2052     22  2011      0
# 2        Jordan B. Peterson     4.7    18979     15  2018      1
# 3             George Orwell     4.7    21424      6  2017      0
# 4  National Geographic Kids     4.8     7665     12  2019      1

# %%
dta.tail()
# Out:
#                                                   Name       Author  Rating  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney     4.9
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero     4.7
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero     4.7
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero     4.7
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero     4.7
#
#      Reviews  Price  Year  Genre
# 545     9413      8  2019      0
# 546    14331      8  2016      1
# 547    14331      8  2017      1
# 548    14331      8  2018      1
# 549    14331      8  2019      1

# %% [markdown]
# <b>
# <b>
# <b>
# <b>
# <b>
# <b>

# %% [markdown]
# We can see from the tail of our dataset that there are the same book, a multiple time.
#
# The only difference is the year, in term of features. We can imagine that it represent the year when the book pop_up or the year when it becomes a bestsellers.
# After a quick verification on internet, we can see that it represents: The year when the book was past of bestsellings.
# Lets create a feature representing the time the book had been a bestsellings.
#
# In the next steps, we will treat this problematic.

# %% [markdown]
# ## c. Preprocessing

# %% [markdown]
# ## -- Cleaning of "Name" column: case sentivity
# Due to case sensitivity, the same book, with a different writing, can be misinterpreted to a different one.
# We can correct this errors of case sensitivity by putting all the name in upper case.

# %%
dta["Name"] = dta["Name"].str.upper()

# %% [markdown]
# ## -- Cleaning of "Author" column
#
# We identified some difference for the reference of some authors, such as J.K Rowling. To fix this error, we smooth out the author name to J.K Rowling (without space between ".")

# %%
#To correct the space problem for few authors
for index, value in dta["Author"].items():
    if value.startswith("J."):
        change = value.replace(" ","")
        dta.loc[index, "Author"] = change
    else:
        pass

# %%
plt.figure(figsize=(10,6))

ax = sns.countplot(data=dta, x=dta.Name.value_counts(), palette="Set2");

for p in ax.patches:
    ax.annotate(format(p.get_height(), 'd'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha = 'center', va = 'center',
                   xytext = (0, 9),
                   textcoords = 'offset points')

ax.set(xlabel="Appearances", ylabel="Count");
ax.set_title("Times a Title Shows up on Top 50 Charts (2009-2019)");
plt.show();

# %%
dta_repeat = pd.DataFrame([x, y] for x, y in dta.Author.value_counts().iteritems() if (y > 1))
dta_repeat.columns = ['Author','Top 50 Appearances']
dta_repeat.columns
# Out:
# Index(['Author', 'Top 50 Appearances'], dtype='object')

# %%
#Looking for redundancy in the authors

plt.figure(figsize=(10,6))

ax = sns.countplot(data=dta, x=dta.Author.value_counts(), palette="Set2")

for p in ax.patches:
    ax.annotate(format(p.get_height(), 'd'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha = 'center', va = 'center',
                   xytext = (0, 9),
                   textcoords = 'offset points')

ax.set(xlabel="Appearances", ylabel="Number of Authors")
ax.set_title("Total Appearances in the Top 50 Charts")
plt.show()

# %% [markdown]
# ## d. Basic statistics

# %% [markdown]
# ## -- Look for correlation

# %%
numerical = list(set(dta.columns) -
                 set(['Name','Author']))
corr_matrix = dta[numerical].corr()

sns.heatmap(corr_matrix, annot=True);
plt.xticks(rotation=45);

print(corr_matrix)
# Out:
#           Reviews     Price    Rating      Year     Genre
# Reviews  1.000000 -0.109182 -0.001729  0.263560 -0.280058
# Price   -0.109182  1.000000 -0.133086 -0.153979  0.182761
# Rating  -0.001729 -0.133086  1.000000  0.242383 -0.116282
# Year     0.263560 -0.153979  0.242383  1.000000  0.020868
# Genre   -0.280058  0.182761 -0.116282  0.020868  1.000000

# %% [markdown]
# ## -- Step Outlier detection

# %%
dta_quanti = dta[dta.columns.difference(["Name", "Author"])]
c = 'steelblue'
blue_dict =  {'patch_artist': True,
             'boxprops': dict(color=c, facecolor='w'),
             'capprops': dict(color=c),
             'flierprops': dict(color=c, markeredgecolor=c,marker="."),
             'medianprops': dict(color=c),
             'whiskerprops': dict(color=c)}

plt.close()
plt.figure(figsize=(15,10))
for i in np.arange(start=0,stop=dta_quanti.shape[1]):
    plt.subplot(4, 4, i+1)
    plt.boxplot(dta_quanti.iloc[:,i],**blue_dict)
    plt.xlabel(dta_quanti.columns[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## -- Bivariate analysis

# %%
#With genre 0 = Fiction, genre 1 = Non fiction
sns.pairplot(dta, hue='Genre',vars=['Reviews', 'Price', 'Year', 'Rating'],markers='o')

# %% [markdown]
# ## 3. Features engineering

# %% [markdown]
# ## --Features creation

# %% [markdown]
# ###  -- Creation of "sum_best" column
#
# From the previosu graph we decided to create a column: "sum_best". This column correspond to the number of year a book had been in the best bestsellings within the last 10 years.

# %%
dta["sum_best"]=""
dta["sum_best"] = dta.groupby("Name").transform('count')
dta.tail()
# Out:
#                                                   Name       Author  Rating  \
# 545       WRECKING BALL (DIARY OF A WIMPY KID BOOK 14)  Jeff Kinney     4.9
# 546  YOU ARE A BADASS: HOW TO STOP DOUBTING YOUR GR...  Jen Sincero     4.7
# 547  YOU ARE A BADASS: HOW TO STOP DOUBTING YOUR GR...  Jen Sincero     4.7
# 548  YOU ARE A BADASS: HOW TO STOP DOUBTING YOUR GR...  Jen Sincero     4.7
# 549  YOU ARE A BADASS: HOW TO STOP DOUBTING YOUR GR...  Jen Sincero     4.7
#
#      Reviews  Price  Year  Genre  sum_best
# 545     9413      8  2019      0         1
# 546    14331      8  2016      1         4
# 547    14331      8  2017      1         4
# 548    14331      8  2018      1         4
# 549    14331      8  2019      1         4

# %% [markdown]
# ### -- Add of a weighted review column

# %%
#Give an information on the dataset with the cosidered "best movies", with minimum 3000 review
data_order = dta.groupby(['Name', 'Author', 'Genre'], as_index=False)[['Rating', 'Reviews']].mean()
data_order = data_order[data_order['Reviews']>3000]
data_order = data_order.sort_values('Rating', ascending=False).head(20)
data_order
# Out:
#                                                   Name                 Author  \
# 177                        OBAMA: AN INTIMATE PORTRAIT             Pete Souza
# 197  RUSH REVERE AND THE FIRST PATRIOTS: TIME-TRAVE...          Rush Limbaugh
# 117  HARRY POTTER AND THE PRISONER OF AZKABAN: THE ...            J.K.Rowling
# 118  HARRY POTTER AND THE SORCERER'S STONE: THE ILL...            J.K.Rowling
# 112                           HAMILTON: THE REVOLUTION     Lin-Manuel Miranda
# 108  GOODNIGHT, GOODNIGHT CONSTRUCTION SITE (HARDCO...   Sherri Duskey Rinker
# 36            BROWN BEAR, BROWN BEAR, WHAT DO YOU SEE?        Bill Martin Jr.
# 311                   THE WONDERFUL THINGS YOU WILL BE  Emily Winfield Martin
# 66   DOG MAN AND CAT KID: FROM THE CREATOR OF CAPTA...             Dav Pilkey
# 208             STRANGE PLANET (STRANGE PLANET SERIES)         Nathan W. Pyle
# 67   DOG MAN: A TALE OF TWO KITTIES: FROM THE CREAT...             Dav Pilkey
# 68   DOG MAN: BRAWL OF THE WILD: FROM THE CREATOR O...             Dav Pilkey
# 114  HARRY POTTER AND THE CHAMBER OF SECRETS: THE I...            J.K.Rowling
# 70   DOG MAN: FOR WHOM THE BALL ROLLS: FROM THE CRE...             Dav Pilkey
# 69   DOG MAN: FETCH-22: FROM THE CREATOR OF CAPTAIN...             Dav Pilkey
# 329                             UNFREEDOM OF THE PRESS          Mark R. Levin
# 151  LAST WEEK TONIGHT WITH JOHN OLIVER PRESENTS A ...             Jill Twiss
# 348       WRECKING BALL (DIARY OF A WIMPY KID BOOK 14)            Jeff Kinney
# 266               THE LEGEND OF ZELDA: HYRULE HISTORIA         Patrick Thorpe
# 273                                 THE MAGNOLIA STORY            Chip Gaines
#
#      Genre  Rating  Reviews
# 177      1     4.9   3192.0
# 197      0     4.9   3836.0
# 117      0     4.9   3146.0
# 118      0     4.9  10052.0
# 112      1     4.9   5867.0
# 108      0     4.9   7038.0
# 36       0     4.9  14344.0
# 311      0     4.9   8842.0
# 66       0     4.9   5062.0
# 208      0     4.9   9382.0
# 67       0     4.9   4786.0
# 68       0     4.9   7235.0
# 114      0     4.9  19622.0
# 70       0     4.9   9089.0
# 69       0     4.9  12619.0
# 329      1     4.9   5956.0
# 151      0     4.9  11881.0
# 348      0     4.9   9413.0
# 266      0     4.9   5396.0
# 273      1     4.9   7861.0

# %% [markdown]
# Use of weighted mean to attribute a review/rating which corresponds more to the reality field
#
# with W_mean = ( ( v / m+v) * R) (( m / m+v)*C)
#
# m = number of rating
#
# C = mean Review
#
# v= number of review
#
# R = average numb of rating

# %%
# Weighted rating
m = min(dta['Reviews'])
C = dta['Rating'].mean()
def weighted_rating(x, m=m, C=C):
    v = x['Reviews']
    R = x['Rating']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
dta['Weighted Rating'] = dta.apply(weighted_rating, axis=1)

# %%
dta.groupby(['Name','Author','Genre'], as_index=False)[['Rating', 'Reviews', 'Weighted Rating']].mean().sort_values(by='Weighted Rating', ascending=False).head(10)
# Out:
#                                                   Name           Author  \
# 178                          OH, THE PLACES YOU'LL GO!        Dr. Seuss
# 114  HARRY POTTER AND THE CHAMBER OF SECRETS: THE I...      J.K.Rowling
# 139  JESUS CALLING: ENJOYING PEACE IN HIS PRESENCE ...      Sarah Young
# 309                        THE VERY HUNGRY CATERPILLAR       Eric Carle
# 36            BROWN BEAR, BROWN BEAR, WHAT DO YOU SEE?  Bill Martin Jr.
# 69   DOG MAN: FETCH-22: FROM THE CREATOR OF CAPTAIN...       Dav Pilkey
# 151  LAST WEEK TONIGHT WITH JOHN OLIVER PRESENTS A ...       Jill Twiss
# 118  HARRY POTTER AND THE SORCERER'S STONE: THE ILL...      J.K.Rowling
# 348       WRECKING BALL (DIARY OF A WIMPY KID BOOK 14)      Jeff Kinney
# 208             STRANGE PLANET (STRANGE PLANET SERIES)   Nathan W. Pyle
#
#      Genre  Rating  Reviews  Weighted Rating
# 178      0     4.9  21834.0         4.899524
# 114      0     4.9  19622.0         4.899470
# 139      1     4.9  19576.0         4.899469
# 309      0     4.9  19546.0         4.899468
# 36       0     4.9  14344.0         4.899275
# 69       0     4.9  12619.0         4.899177
# 151      0     4.9  11881.0         4.899126
# 118      0     4.9  10052.0         4.898967
# 348      0     4.9   9413.0         4.898897
# 208      0     4.9   9382.0         4.898894

# %%
dta = dta.drop("Rating", axis=1)
dta.head(5)
# Out:
#                                                 Name  \
# 0                      10-DAY GREEN SMOOTHIE CLEANSE
# 1                                  11/22/63: A NOVEL
# 2            12 RULES FOR LIFE: AN ANTIDOTE TO CHAOS
# 3                             1984 (SIGNET CLASSICS)
# 4  5,000 AWESOME FACTS (ABOUT EVERYTHING!) (NATIO...
#
#                      Author  Reviews  Price  Year  Genre  sum_best  \
# 0                  JJ Smith    17350      8  2016      1         1
# 1              Stephen King     2052     22  2011      0         1
# 2        Jordan B. Peterson    18979     15  2018      1         1
# 3             George Orwell    21424      6  2017      0         1
# 4  National Geographic Kids     7665     12  2019      1         1
#
#    Weighted Rating
# 0         4.699826
# 1         4.600325
# 2         4.699841
# 3         4.699859
# 4         4.799127

# %%
numerical = list(set(dta.columns) -
                 set(['Name','Author']))
corr_matrix = dta[numerical].corr()

sns.heatmap(corr_matrix, annot=True);
plt.xticks(rotation=45);

# %% [raw]
# ### -- Pivot of the Year column to limit the redundancy in our data

# %% [raw]
# dta_inyear = dta.copy()
# dta_inyear.columns

# %% [raw]
# gr = dta_inyear.groupby(['Year'])
#
# #liste to get the index per year
# total_year = []
# for name,group in gr:
#         total_year.append(group["Name"].index.tolist())
#
# #creation of empty column
# def crea_year_col(df, list_year):
#     for ele in list_year:
#         df[ele] = 0
#     return
#
# #lis of column's name
# years = ["in_2009", "in_2010", "in_2011", "in_2012", "in_2013", "in_2014", "in_2015", "in_2016", "in_2017", "in_2018", "in_2019" ]
# crea_year_col(dta_inyear, years)
#
#
# for numb in range(0, len(total_year)):
#     column_name = years[numb]
#
#     for element in total_year[numb]:
#         dta_inyear.at[element, column_name] = 1

# %% [raw]
# data_fin = dta_inyear.groupby(['Name', 'Author', 'Reviews', 'Price', 'Genre', 'sum_best',
#        'Weighted Rating'], as_index=False)[['in_2009', 'in_2010', 'in_2011', 'in_2012',
#        'in_2013', 'in_2014', 'in_2015', 'in_2016', 'in_2017', 'in_2018',
#        'in_2019']].sum()

# %% [raw]
# # Now drop of the year column
# data_fin.columns

# %% [raw]
# data_fin

# %% [raw]
# numerical = list(set(data_fin.columns) -
#                  set(['Name','Author']))
# corr_matrix = data_fin[numerical].corr()
#
# fig, ax = plt.subplots(figsize=(15,15))
# sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax);
# plt.xticks(rotation=45);

# %% [raw]
# data_fin["Name"].value_counts().head(13)

# %% [markdown]
# We constat there are still smme books wich are count multiple time, after a closer look on data we see that their price is changing over time.

# %% [markdown]
# # 4. Modelisation

# %% [markdown]
# ## -- List of model we will use for our binairy classification
#
# ## During this step we have a first look on the results for each model, from this results we will then change the paremters to optimize results
#
# Note that we have to be careful with the rzegulaization step with the algorithm based on euclidian distance.
#
# #Parametric
# - Logistic Regression.
# - Perceptron
# - Naive Bayes.
#
# #Non parametric
# - Decision Trees.
# - Support Vector Machine.
# - k-Nearest Neighbors.

# %%
dta_mod = dta[dta.columns.difference(["Name", "Author", "Year"])]
dta_mod.columns
# Out:
# Index(['Genre', 'Price', 'Reviews', 'Weighted Rating', 'sum_best'], dtype='object')

# %%
#impot of pck for modelisation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

from sklearn.model_selection import train_test_split
from warnings import simplefilter
from sklearn import model_selection
from sklearn.preprocessing import  StandardScaler
from multiprocessing import Pool
import os
import warnings
from sklearn.exceptions import DataConversionWarning

# %% [markdown]
# ## -- train test split for parametrics models

# %%
# definition of train: + train test slpit of data

seed = 7
validation_size = 0.5
scoring="accuracy"


#shuffle of the data
dta_mod = dta_mod.sample(frac=1).reset_index(drop=True)

X = dta_mod.loc[:, dta_mod.columns != 'Genre'].to_numpy().astype("int8")
y = dta_mod.loc[:,"Genre"].to_numpy().astype("int8")

ss = StandardScaler()
X_s = ss.fit_transform(X)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X_s, y, test_size=validation_size, random_state=seed)

# %%
parametric_models = []

parametric_models.append(('LR', LogisticRegression()))
parametric_models.append(('GauNB', GaussianNB()))

parametric_results=[]
parametric_names=[]

# %%
Lname=[parametric_models[0][0], parametric_models[1][0]]
Lmodel=[parametric_models[0][1], parametric_models[1][1]]

# %%
def prediction(N,M):
#for name,model in models:
    from warnings import simplefilter
    simplefilter(action='ignore', category=FutureWarning)

    cv_results=model_selection.cross_val_score(M,X_train,y_train,cv=10,scoring=scoring)
    results.append(cv_results)
    names.append(N)
    msg = "%s: %f (%f)" % (N, cv_results.mean(), cv_results.std())
    print(msg)
    return

# %%
Lgt_accuracy = prediction(parametric_models[0][0], parametric_models[0][1])
GauNB_accuracy =  prediction(parametric_models[1][0], parametric_models[1][1])
# Out:
# LR: 0.622354 (0.069126)
# GauNB: 0.581746 (0.018260)

# %% [markdown]
# ## -- train test split for  NON parametrics models

# %%
# definition of train: + train test slpit of data

seed = 9
validation_size = 0.2
scoring="accuracy"


#shuffle of the data
dta_mod = dta_mod.sample(frac=1).reset_index(drop=True)

X2 = dta_mod.loc[:, dta_mod.columns != 'Genre'].to_numpy().astype("int8")
y2 = dta_mod.loc[:,"Genre"].to_numpy().astype("int8")

ss2 = StandardScaler()
X_s2 = ss.fit_transform(X)

X_train2, X_test2, y_train2, y_test2 = model_selection.train_test_split(X_s2, y2, test_size=validation_size, random_state=seed)

# %%
NONparametric_models = []

NONparametric_models.append(('RDF', RandomForestClassifier(n_estimators=100)))
NONparametric_models.append(('KNN', KNeighborsClassifier()))
NONparametric_models.append(('SVC', SVC(gamma='auto')))

NONparametric_results=[]
NONparametric_names=[]

# %%
Lname2=[NONparametric_models[0][0], NONparametric_models[1][0], NONparametric_models[2][0]]
Lmodel2=[NONparametric_models[0][1], NONparametric_models[1][1], NONparametric_models[2][1]]

# %%
RDF_accuracy = prediction(NONparametric_models[0][0], NONparametric_models[0][1])
KNN_accuracy =  prediction(NONparametric_models[1][0], NONparametric_models[1][1])
SVC_accuracy =  prediction(NONparametric_models[2][0], NONparametric_models[2][1])
# Out:
# RDF: 0.738889 (0.107456)
# KNN: 0.639947 (0.091054)
# SVC: 0.589815 (0.083747)

# %% [markdown]
# # Adjusting hyperparameters
